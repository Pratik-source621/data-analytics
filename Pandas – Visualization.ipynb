# %% [markdown]
# # Pandas – Visualization

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),
                index=pd.date_range('1/1/2000',periods=10), 
                columns=list(['A','D']))
print(df)
df.plot()
# Out:
#                    A         D
# 2000-01-01  0.534877 -1.308406
# 2000-01-02  0.163834 -1.121718
# 2000-01-03 -0.088835 -0.836703
# 2000-01-04 -0.030647  0.281507
# 2000-01-05  0.448696  0.349659
# 2000-01-06 -0.405612  0.721821
# 2000-01-07  0.929856 -0.783284
# 2000-01-08 -1.330305 -1.610191
# 2000-01-09  0.635964  0.334197
# 2000-01-10 -1.055518  0.307728

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.bar()
# Out:
#           a         b         c         d
# 0  0.242112  0.782582  0.731643  0.668000
# 1  0.605539  0.165698  0.084716  0.003972
# 2  0.484144  0.261709  0.963668  0.511980
# 3  0.959540  0.892528  0.682804  0.260067
# 4  0.166451  0.922311  0.977348  0.167200
# 5  0.629526  0.854961  0.610438  0.627902
# 6  0.683740  0.681814  0.682751  0.884215
# 7  0.770609  0.826797  0.421261  0.749628
# 8  0.224863  0.886446  0.330257  0.493371
# 9  0.512238  0.894338  0.964078  0.982300
# <Axes: >

# %%
import pandas as pd
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.bar(stacked=True)
# Out:
#           a         b         c         d
# 0  0.792702  0.388678  0.128903  0.221050
# 1  0.122917  0.792782  0.265403  0.152613
# 2  0.800020  0.659307  0.239241  0.911109
# 3  0.627709  0.115654  0.401584  0.800205
# 4  0.480770  0.349274  0.194232  0.570168
# 5  0.144625  0.670571  0.906304  0.942983
# 6  0.912824  0.438893  0.580219  0.879286
# 7  0.100051  0.284369  0.816805  0.528767
# 8  0.739852  0.291086  0.653190  0.588897
# 9  0.959223  0.035572  0.851271  0.436540
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.barh(stacked=True)
# Out:
#           a         b         c         d
# 0  0.637519  0.003958  0.178418  0.593847
# 1  0.008022  0.041369  0.056857  0.333433
# 2  0.941148  0.445380  0.442674  0.182119
# 3  0.387946  0.612964  0.112820  0.214304
# 4  0.957964  0.607062  0.173242  0.442529
# 5  0.615322  0.045857  0.436047  0.437527
# 6  0.833269  0.483739  0.389338  0.560275
# 7  0.556758  0.757105  0.725905  0.393970
# 8  0.765532  0.724371  0.017514  0.743076
# 9  0.596799  0.644443  0.175227  0.188362

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.randn(1000)+8,'b':np.random.randn(1000),'c':np.random.randn(1000) - 3}, columns=['a', 'b', 'c'])
print(df)
df.plot.hist(bins=20)
# Out:
#              a         b         c
# 0     9.470253 -1.768848 -2.991851
# 1     7.875353 -0.385481 -2.758393
# 2     9.089414 -1.516208 -2.612765
# 3     8.889284 -0.292802 -4.460719
# 4     7.521835  1.844995 -3.217857
# 5     6.940552  2.105643 -4.892369
# 6     7.048384  0.081328 -3.576057
# 7     7.400182 -0.502180 -3.921249
# 8     7.815865 -1.045934 -4.314165
# 9     7.813007  1.820560 -0.736232
# 10    7.719909  1.205668 -1.687226
# 11    9.289172  2.232652 -4.444630
# 12    6.540701  0.529207 -4.815252
# 13    9.190060  0.259978 -4.044310
# 14    7.905905  1.165929 -4.172846
# 15    7.647305  0.709079 -1.881953
# 16    7.733874 -0.274185 -1.556418
# 17    7.698191 -0.921376 -3.382757
# 18    6.281128 -2.090198 -2.451719
# 19    8.146571 -0.018244 -2.334121
# 20    7.958708  2.119843 -3.687792
# 21    8.351659 -0.944794 -3.188671
# 22    7.939408  0.009222 -4.024930
# 23    8.286162 -0.558364 -4.485028
# 24    8.069029 -1.643842 -1.809957
# 25    8.912962  2.013162 -3.372887
# 26    7.249910 -0.703518 -0.656016
# 27    7.214269  0.367182 -3.062232
# 28    8.800188 -1.534986 -2.978057
# 29    7.106551  1.489066 -1.619346
# ..         ...       ...       ...
# 970   7.073886  0.810381 -3.170226
# 971   8.103743  0.782106 -4.196073
# 972   8.199746 -0.580153 -2.978055
# 973   6.978150 -0.750764 -3.216698
# 974   8.070884 -0.568644 -1.651642
# 975   6.590400  1.549086 -2.969885
# 976   7.277844 -0.070327 -3.916470
# 977   7.579209  1.236629 -2.716172
# 978   7.723973  0.587189 -2.681456
# 979   9.483749  0.844143 -2.593260
# 980   8.266531  1.194074 -3.806032
# 981   9.480156 -1.691528 -4.524335
# 982   8.594941 -0.157002 -3.606391
# 983   7.816535 -1.853332 -2.008525
# 984   6.530960 -0.390634 -3.143412
# 985   8.634483  0.476481 -2.209075
# 986   7.991738  0.201128 -3.074063
# 987   8.990067  0.872447 -6.809289
# 988   7.626768  0.491423 -3.428770
# 989   7.179733  0.823145 -2.700587
# 990   7.631851 -1.340437 -4.477792
# 991  10.222945  0.961856 -0.199398
# 992   6.500993  0.760520 -1.664875
# 993   7.826224  0.643386 -3.957109
# 994   7.368375 -1.045513 -3.296494
# 995   9.629946 -1.468436 -4.189303
# 996   7.183060 -0.450525 -2.534165
# 997   8.452288 -0.311108 -2.581625
# 998   7.229016 -1.019545 -4.400342
# 999   8.587049  0.547328 -2.995159
#
# [1000 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
print(df)
df.plot.box()
# Out:
#           A         B         C         D         E
# 0  0.503516  0.433740  0.519644  0.044122  0.326240
# 1  0.402819  0.846014  0.628672  0.600780  0.344511
# 2  0.808858  0.144915  0.941095  0.457959  0.574193
# 3  0.348372  0.158294  0.497244  0.996521  0.035679
# 4  0.623055  0.668129  0.305490  0.350160  0.249591
# 5  0.783522  0.053665  0.887971  0.766637  0.061138
# 6  0.232681  0.621941  0.219568  0.025408  0.250909
# 7  0.100979  0.503406  0.189852  0.950884  0.761544
# 8  0.799033  0.825183  0.185366  0.377399  0.075636
# 9  0.430174  0.207749  0.671300  0.799740  0.733333
# <Axes: >

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 4), 
                  columns=['a', 'b', 'c', 'd'])
print(df)
df.plot.area()
# Out:
#           a         b         c         d
# 0  0.850812  0.322241  0.665029  0.587896
# 1  0.856372  0.681030  0.112483  0.485070
# 2  0.991902  0.264864  0.248512  0.222814
# 3  0.703122  0.562827  0.791658  0.933377
# 4  0.713821  0.683708  0.432180  0.620618
# 5  0.684173  0.358381  0.257799  0.810372
# 6  0.811047  0.934714  0.529869  0.462760
# 7  0.281459  0.393253  0.043442  0.575968
# 8  0.669515  0.601227  0.302941  0.676314
# 9  0.702659  0.674286  0.239256  0.306343
# <Axes: >

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
print(df)
df.plot.scatter(x='a', y='d')
# Out:
#            a         b         c         d
# 0   0.165363  0.804052  0.106011  0.722293
# 1   0.242895  0.274254  0.806632  0.918459
# 2   0.983076  0.789236  0.270582  0.948768
# 3   0.204414  0.500020  0.069967  0.563404
# 4   0.578107  0.174139  0.588412  0.293548
# 5   0.465135  0.296953  0.982890  0.053989
# 6   0.511085  0.629589  0.106462  0.105992
# 7   0.443255  0.696844  0.206314  0.327983
# 8   0.621549  0.602125  0.391622  0.715402
# 9   0.405603  0.690706  0.872652  0.364671
# 10  0.360913  0.181917  0.861318  0.032513
# 11  0.374399  0.849535  0.460884  0.827402
# 12  0.922705  0.624312  0.943048  0.747860
# 13  0.086587  0.715244  0.994406  0.108306
# 14  0.663236  0.017294  0.754931  0.326719
# 15  0.066972  0.236221  0.282133  0.224107
# 16  0.306562  0.958940  0.036494  0.487597
# 17  0.951485  0.907115  0.704926  0.728274
# 18  0.613240  0.894851  0.583552  0.579746
# 19  0.496255  0.329246  0.793357  0.484219
# 20  0.435990  0.919021  0.322552  0.793719
# 21  0.409759  0.818625  0.923072  0.272671
# 22  0.903289  0.502489  0.642725  0.391388
# 23  0.110262  0.860851  0.410370  0.742803
# 24  0.127582  0.725240  0.087084  0.195953
# 25  0.261144  0.161490  0.010193  0.123960
# 26  0.886358  0.605984  0.497785  0.246187
# 27  0.545248  0.293399  0.926347  0.051845
# 28  0.190126  0.921723  0.674803  0.394629
# 29  0.996328  0.010063  0.371288  0.228529
# 30  0.129527  0.296682  0.872227  0.242268
# 31  0.661845  0.843364  0.831924  0.437319
# 32  0.703169  0.360261  0.960042  0.542136
# 33  0.529058  0.199810  0.269037  0.556342
# 34  0.612750  0.091723  0.787410  0.193377
# 35  0.845737  0.146863  0.775866  0.798963
# 36  0.682149  0.004549  0.638393  0.336360
# 37  0.054920  0.296219  0.706077  0.930966
# 38  0.749494  0.998574  0.973022  0.375806
# 39  0.662186  0.878956  0.731513  0.081912
# 40  0.019126  0.539334  0.803650  0.863105
# 41  0.011859  0.178232  0.147528  0.187148
# 42  0.310012  0.219278  0.386416  0.616791
# 43  0.229600  0.648870  0.140487  0.976094
# 44  0.886150  0.735424  0.628200  0.952289
# 45  0.584429  0.184091  0.622286  0.461197
# 46  0.421621  0.670674  0.525280  0.596518
# 47  0.759305  0.080180  0.378923  0.873731
# 48  0.576436  0.116476  0.157378  0.203520
# 49  0.420424  0.254853  0.396764  0.388198

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], 
                  columns=['x'])
print(df)
df.plot.pie(subplots=True)
# Out:
#           x
# a  1.053104
# b  1.205743
# c  1.549254
# d  1.935174
# array([<Axes: ylabel='x'>], dtype=object)
