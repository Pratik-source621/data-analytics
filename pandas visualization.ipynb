# %%
import pandas as pd
import numpy as np


# Creating empty series
ser = pd.Series()

print(ser)

# simple array
data = np.array(['g', 'e', 'e', 'k', 's'])

ser = pd.Series(data)
print(ser)
# Out:
# Series([], dtype: float64)
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import numpy as np
import pandas as pd
randInt = np.random.randn(20,5)
index = pd.date_range('1/1/2000', periods=20)
columns = list('ABCDE')
df = pd.DataFrame(randInt, index=index, columns=columns)
print(df)
df.plot()
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.731617 -0.264594  0.208946 -0.477400 -0.909944
# 2000-01-02  0.933243  1.010139  0.349132  1.479078  0.277726
# 2000-01-03 -0.274041  1.452929  0.064464 -0.058425 -0.814387
# 2000-01-04  0.636840 -0.682362  0.762047  0.577494 -0.600689
# 2000-01-05  0.055598  0.024034 -0.591466  1.472868 -0.350748
# 2000-01-06  1.105915  0.547951 -1.220912 -0.016512  2.148963
# 2000-01-07 -0.778956 -0.045424 -0.568014  0.086114  1.049397
# 2000-01-08  0.403414  0.185133  0.012259  1.560941 -0.723395
# 2000-01-09 -1.114996  0.285295 -1.798664  0.101564 -1.137652
# 2000-01-10 -0.427006 -1.586424  0.440458  0.270189  1.031260
# 2000-01-11  1.773744  0.355402 -0.136162 -0.328286  0.923972
# 2000-01-12  0.578870 -0.885916 -1.333738  0.173971  1.723827
# 2000-01-13  0.663571  0.474289 -0.993523  0.676836 -0.625603
# 2000-01-14 -0.061188 -0.198520 -1.151206  0.379422 -0.152231
# ...

# %%
import numpy as np
import pandas as pd
randInt = np.random.randn(20,5)
index = pd.date_range('1/1/2000', periods=20)
columns = list('ABCDE')
df = pd.DataFrame(randInt, index=index, columns=columns)
print(df)
df.plot.bar()
# Out:
#                    A         B         C         D         E
# 2000-01-01 -1.477080  1.178211 -1.492978 -0.737689 -0.511234
# 2000-01-02 -0.580440 -0.172869  1.205273 -0.699040  1.304700
# 2000-01-03  0.033490  0.453772 -1.867859  1.279036  0.913626
# 2000-01-04  1.999575 -0.777499  1.004294 -1.013961 -0.901123
# 2000-01-05  0.619591 -0.320146 -0.918636  0.077644  1.638754
# 2000-01-06 -0.775462  1.485153 -1.181291 -0.380605  1.174145
# 2000-01-07  0.459941 -0.246309  0.468919  0.404651  1.027555
# 2000-01-08  1.587985  0.012373 -1.240590  0.108217  0.309330
# 2000-01-09 -2.491444 -0.253759  0.071722  0.610399 -0.393458
# 2000-01-10  0.266459  0.948986 -0.891965 -1.548902 -1.554009
# 2000-01-11  0.365764  0.148183 -0.045788 -0.160689 -1.610081
# 2000-01-12  0.746965  1.166723 -0.000201  0.143575  0.142151
# 2000-01-13 -1.336853  0.902119 -0.431595  0.035030 -0.130012
# 2000-01-14 -0.374581 -0.097264  0.634119  0.225925  0.168258
# ...

# %%
import numpy as np
import pandas as pd
randInt = np.random.rand(20,5)
index = pd.date_range('1/1/2000', periods=20)
columns = list('ABCDE')
df = pd.DataFrame(randInt, index=index, columns=columns)
print(df)
df.plot.bar(stacked=True)
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.524918  0.437506  0.979671  0.385508  0.792652
# 2000-01-02  0.524839  0.416585  0.327224  0.478116  0.660484
# 2000-01-03  0.499996  0.903948  0.443106  0.765136  0.867831
# 2000-01-04  0.969228  0.639347  0.725505  0.519878  0.491231
# 2000-01-05  0.869473  0.652332  0.059473  0.402700  0.109671
# 2000-01-06  0.724071  0.181648  0.033340  0.039181  0.853536
# 2000-01-07  0.006258  0.085438  0.549512  0.681557  0.979224
# 2000-01-08  0.888141  0.370473  0.241808  0.859051  0.706851
# 2000-01-09  0.474185  0.896722  0.079578  0.515801  0.529829
# 2000-01-10  0.246639  0.927019  0.864934  0.719788  0.736545
# 2000-01-11  0.232107  0.219267  0.966445  0.879296  0.415998
# 2000-01-12  0.152148  0.675774  0.772765  0.662914  0.704730
# 2000-01-13  0.880824  0.718604  0.194387  0.203706  0.481583
# 2000-01-14  0.393079  0.131520  0.084928  0.370395  0.092601
# ...

# %%
# import pandas as pd
import pandas as pd
 
# simple array
data = [1, 2, 3, 4]
 
ser = pd.Series(data)
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
import pandas as pd 
import numpy as np
list1 = ['a','b','c','d']
data = np.array(list1)
s = pd.Series(data)

print("Numpy data Represitataion \n,",data,"\n")

print("pandas series Represitation \n",s,"\n")
# Out:
# Numpy data Represitataion
# , ['a' 'b' 'c' 'd']
#
# pandas series Represitation
#  0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd 

s= pd.Series ([1,2,3,4,5], index = ['a','b','c','d','e'])
print (s[:3])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
import pandas as pd 

s= pd.Series ([1,2,3,4,5], index = ['a','b','c','d','e'])
print (s[-3:])
# Out:
# c    3
# d    4
# e    5
# dtype: int64

# %%
import pandas as pd 
s= pd.Series([1,2,3,4,5],index= ['a','b','c','d','e'])
print (s['a'],s['b'],s['e'])
# Out:
# 1 2 5

# %%
import pandas as pd 
s= pd.Series([1,2,3,4,5],index= ['a','b','c','d','e'])
print (s['a'],s['b'],s['e'])

multi1 = s ['b'] * s['c'] *s['d']
print(multi1)
# Out:
# 1 2 5
# 24

# %%
import pandas as pd
data = [['lokesh',20],['harish',12],['pravin',13]]
df = pd.DataFrame(data,columns = ['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0  lokesh   20
# 1  harish   12
# 2  pravin   13

# %%
import pandas as pd 
data ={'name ':['messi','ronaldo','neymar','pele'],'Age':[28,34,29,42]}
df= pd.DataFrame(data,index=['rank1','rank2','rank3','rank4'])
print (df)
# Out:
#          name   Age
# rank1    messi   28
# rank2  ronaldo   34
# rank3   neymar   29
# rank4     pele   42

# %%
import pandas as pd 
data = {'one':pd.Series([1,2,3])}
